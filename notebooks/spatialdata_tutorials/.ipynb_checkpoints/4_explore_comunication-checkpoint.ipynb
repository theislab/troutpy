# %% [markdown]
# # 4. Explore communication by exRNA

# %% [markdown]
# Transcripts located outside segmented cells are more likely to play a role in celular communication, being located outside their cell of origin and close to other populations. Thus, in the following notebook we aim to explore the commnunication patterns where exRNA could be involved

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import spatialdata as sd
import troutpy

# %% [markdown]
# ## Read SpatialData object

# %%
xenium_path_cropped = "/media/sergio/Discovair_final/mousebrain_prime_crop_points2regions_annotated.zarr"
output_path = "/media/sergio/Discovair_final/analysis_crop"
sdata = sd.read_zarr(xenium_path_cropped)

# %% [markdown]
# ## Identify source cell of exRNA

# %% [markdown]
# We will use the function `compute_source_cells` to identify the source cell types that may contribute to the extracellular RNA detected in spatial transcriptomics data. For this, we use an expression threshold to determine which transcripts are expressed and computes the proportion of cells expressing each gene per cell type.

# %%
troutpy.tl.compute_source_score(sdata,layer="transcripts",gene_id_column="feature_name",xcoord="x",
ycoord="y",lambda_decay=0.1, copy=False,celltype_key='cell type')
# Out:
# Processing genes:   2%|▏         | 78/4226 [00:16<14:16,  4.85it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 troutpy.tl.compute_source_score(sdata,layer="transcripts",gene_id_column="feature_name",xcoord="x",
#       2 ycoord="y",lambda_decay=0.1, copy=False,celltype_key='cell type')
#
# File ~/Jnotebooks/exRNA/troutpy/src/troutpy/tl/source_cell.py:358, in compute_source_score(sdata, layer, gene_id_column, xcoord, ycoord, lambda_decay, copy, celltype_key)
#     356         closet_cell_table.loc[transcript_idx, "closest_celltype"] = cell_type_min[i]
#     357         for cell_type in all_cell_types:
# --> 358             probabilities_table.loc[transcript_idx, cell_type] = scores_i[types_i == cell_type].sum()
#     360 # We format all probabilieies as an anndata, stored in sdata.tables['source_score']
#     361 prob_table = sc.AnnData(probabilities_table)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:907, in _LocationIndexer.__setitem__(self, key, value)
#     905     maybe_callable = com.apply_if_callable(key, self.obj)
#     906     key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 907 indexer = self._get_setitem_indexer(key)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:774, in _LocationIndexer._get_setitem_indexer(self, key)
#     771 if isinstance(key, tuple):
#     772     with suppress(IndexingError):
#     773         # suppress "Too many indexers"
# --> 774         return self._convert_tuple(key)
#     776 if isinstance(key, range):
#     777     # GH#45479 test_loc_setitem_range_key
#     778     key = list(key)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:989, in _LocationIndexer._convert_tuple(self, key)
#     985 @final
#     986 def _convert_tuple(self, key: tuple) -> tuple:
#     987     # Note: we assume _tupleize_axis_indexer has been called, if necessary.
#     988     self._validate_key_length(key)
# --> 989     keyidx = [self._convert_to_indexer(k, axis=i) for i, k in enumerate(key)]
#     990     return tuple(keyidx)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:989, in <listcomp>(.0)
#     985 @final
#     986 def _convert_tuple(self, key: tuple) -> tuple:
#     987     # Note: we assume _tupleize_axis_indexer has been called, if necessary.
#     988     self._validate_key_length(key)
# --> 989     keyidx = [self._convert_to_indexer(k, axis=i) for i, k in enumerate(key)]
#     990     return tuple(keyidx)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1483, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1480 # Slices are not valid keys passed in by the user,
#    1481 # even though they are hashable in Python 3.12
#    1482 contains_slice = False
# -> 1483 if isinstance(key, tuple):
#    1484     contains_slice = any(isinstance(v, slice) for v in key)
#    1486 if is_scalar(key) or (
#    1487     isinstance(labels, MultiIndex) and is_hashable(key) and not contains_slice
#    1488 ):
#    1489     # Otherwise get_loc will raise InvalidIndexError
#    1490
#    1491     # if we are a label return me
#
# KeyboardInterrupt:

# %%
sdata
# Out:
# SpatialData object, with associated Zarr store: /media/sergio/Discovair_final/mousebrain_prime_crop_points2regions_annotated.zarr
# ├── Images
# │     └── 'morphology_focus': DataTree[cyx] (5, 3000, 5000), (5, 1500, 2500), (5, 750, 1250), (5, 375, 625), (5, 188, 312)
# ├── Labels
# │     ├── 'cell_labels': DataTree[yx] (3000, 5000), (1500, 2500), (750, 1250), (375, 625), (188, 312)
# │     └── 'nucleus_labels': DataTree[yx] (3000, 5000), (1500, 2500), (750, 1250), (375, 625), (188, 312)
# ├── Points
# │     └── 'transcripts': DataFrame with shape: (<Delayed>, 17) (3D points)
# ├── Shapes
# │     ├── 'cell_boundaries': GeoDataFrame shape: (1762, 1) (2D shapes)
# │     ├── 'cell_circles': GeoDataFrame shape: (1722, 2) (2D shapes)
# │     └── 'nucleus_boundaries': GeoDataFrame shape: (1750, 1) (2D shapes)
# └── Tables
#       ├── 'segmentation_free_table': AnnData (2114819, 13035)
#       ├── 'source_score': AnnData (834299, 10)
#       ├── 'table': AnnData (1703, 4226)
#       └── 'target_score': AnnData (834299, 10)
# with coordinate systems:
#     ▸ 'global', with elements:
#         morphology_focus (Images), cell_labels (Labels), nucleus_labels (Labels), transcripts (Points), cell_boundaries (Shapes), cell_circles (Shapes), nucleus_boundaries (Shapes)
# with the following elements not in the Zarr store:
#     ▸ source_score (Tables)
#     ▸ target_score (Tables)

# %%
# work on visualization
# filtered_proportions = source_proportion[(source_proportion > 0.1).any(axis=1)]
# absent_source_proportions = source_proportion[np.max(source_proportion,axis=1)<0.1]
# troutpy.pl.sorted_heatmap(source_proportion, output_path,filename="Heatmap_source_cells_by_gene.pdf",cmap='Blues',vmax=0.2)
# troutpy.pl.sorted_heatmap(absent_source_proportions, output_path,filename="Heatmap_source_cells_by_gene.pdf",cmap='Blues',vmax=1,figsize=(4,3))

# %% [markdown]
# ### Compute distance to source cell

# %% [markdown]
# After computing the distance between each cell and its source, we can quantify the proportion of extracellular transcripts located away (distant transcripts) from its closest source. For this, we define a threshold distance ( in micrometers), which will be the minimum distance from each transcript to its source to consider a transcript distance. To compute the proportion of distant transcripts, we will employ the function ``troutpy.tl.compute_distant_cells_prop``

# %%
troutpy.tl.compute_distant_cells_prop(sdata, layer="transcripts", gene_id_column="feature_name", threshold=30, copy=False)
# Out:
# /home/sergio/.local/lib/python3.10/site-packages/troutpy/tl/source_cell.py:243: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   proportions_above_threshold = (data.groupby(gene_id_column)['distance_to_source_cell']

# %% [markdown]
# ### --To do-- work on plotting functions

# %%
## work on plotting
# troutpy.pl.proportion_above_threshold(proportions_above_threshold, top_percentile=0.01, bottom_percentile=0.01, figsize=(5, 10), bar_color="orange",save=True,output_path=output_path)

# %% [markdown]
# ## Explore potential target cell of each exRNA

# %% [markdown]
# Once we have explored the potential source cell of each extracellular transcript, we can also expore the most likely target cell of each exRNA analyzed. For this, we will employ ``troutpy.tl.compute_target_score``. Essentially, this function will compute the distance to its closest cells for each exRNA, using a decay function, based on lambda decay. Of course, we can't be sure that communication will occur with the closest cells. However, in case exRNA plays a role in cell-cell communication, the most likely target cell of each exRNA will be its closest cell.

# %%
troutpy.tl.compute_target_score(sdata, layer="transcripts", gene_id_column="feature_name", xcoord="x",
ycoord="y", xcellcoord="x_centroid", ycellcoord="y_centroid", lambda_decay=0.1,
copy=False, celltype_key="cell type")

# %% [markdown]
# ### --To do-- plotting

# %%
### work on plotting
##troutpy.pl.sorted_heatmap(target_proportion, output_path,filename="Heatmap_target_cells_by_gene.pdf",cmap='Reds',vmax=1)
# troutpy.pl.coupled_scatter(sdata,layer='extracellular_transcripts_enriched',save=False,transcript_group='distance_to_source_cell',size=3,vmax=40,figsize=(6,4))

# %%
sdata['source_score'].obs['feature_name']=sdata['source_score'].obs['feature_name'].astype(str)

# %%
xenium_path_cropped = "/media/sergio/Discovair_final/mousebrain_prime_crop_communication_2.zarr"
sdata.write(xenium_path_cropped, overwrite=True)
# Out:
# INFO     The SpatialData object is not self-contained (i.e. it contains some elements that are Dask-backed from
#          locations outside /media/sergio/Discovair_final/mousebrain_prime_crop_communication_2.zarr). Please see
#          the documentation of `is_self_contained()` to understand the implications of working with SpatialData
#          objects that are not self-contained.
# INFO     The Zarr backing store has been changed from
#          /media/sergio/Discovair_final/mousebrain_prime_crop_communication.zarr the new file path:
#          /media/sergio/Discovair_final/mousebrain_prime_crop_communication_2.zarr

# %%
xenium_path_cropped = "/media/sergio/Discovair_final/mousebrain_prime_crop_communication.zarr"
sdata=sd.read_zarr(xenium_path_cropped)

# %% [markdown]
# # Communication

# %%
troutpy.tl.compute_communication_strength(sdata)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 834299/834299 [03:51<00:00, 3607.83it/s]

# %%
troutpy.tl.gene_specific_interactions(sdata, copy=False)
# Out:
# Processing categories: 100%|████████████████████████████████████████████████████████| 5566/5566 [14:23<00:00,  6.44it/s]

# %%
import scanpy as sc
sc.pl.umap(sdata['table'],color='cell type',palette='jet')

# %%
sdata['table']
# Out:
# AnnData object with n_obs × n_vars = 1703 × 4226
#     obs: 'cell_id', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'region', 'z_level', 'cell_labels', 'n_genes', 'leiden', 'cell type'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells'
#     uns: 'dendrogram_leiden', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'spatialdata_attrs', 'umap', 'cell type_colors'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     layers: 'raw'
#     obsp: 'connectivities', 'distances'

# %%
# Out:
# ['#000080',
#  '#0000ff',
#  '#0060ff',
#  '#00d4ff',
#  '#4dffaa',
#  '#aaff4d',
#  '#ffe600',
#  '#ff7a00',
#  '#ff1300',
#  '#800000']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def plot_celltype_interaction(sdata, kind='heatmap', celltype_key='cell type', vmax=None, vmin=None, cmap='BuPu',
                              dendrogram_ratio=0.1,**kwargs):
    """
    Plot cell type-cell type interaction strength as a heatmap or chord diagram.
    
    Parameters:
    sdata : SpatialData object
        The spatial data object containing interaction scores.
    kind : str, optional
        Type of plot, either 'heatmap' or 'chord'. Default is 'heatmap'.
    celltype_key : str, optional
        Key for cell type colors in `sdata['table'].uns`. Default is 'cell type'.
    vmax : float, optional
        Max value for colormap scaling. Default is None.
    vmin : float, optional
        Min value for colormap scaling. Default is None.
    cmap : str, optional
        Colormap for heatmap or chord diagram. Default is 'BuPu'.
    **kwargs : dict
        Additional arguments passed to the plotting functions.
    """
    interaction_strength = sdata['source_score'].uns['interaction_strength']
    source_table = sdata['source_score']
    target_table = sdata['target_score']
    
    celltype_ints = np.mean(interaction_strength, axis=0)
    celltype_ints_table = pd.DataFrame(celltype_ints, index=source_table.var.index, columns=target_table.var.index)
    
    try:
        colors = sdata['table'].uns[celltype_key + '_colors']
    except KeyError:
        colpalette = plt.get_cmap("tab20")
        colors = [colpalette(i) for i in range(len(np.unique(source_table.var.index)))]
    
    if kind == 'heatmap':
        sns.clustermap(celltype_ints_table, vmax=vmax, vmin=vmin, cmap=cmap, row_colors=colors, col_colors=colors,
                       dendrogram_ratio=dendrogram_ratio, **kwargs).fig.suptitle('Interaction strenght') 
    
    elif kind == 'chord':
        from chord import chord_diagram  # Ensure you have the required package
        chord_diagram(
            celltype_ints,
            source_table.var.index,
            directed=True,
            fontsize=10,
            colors=colors,
            **kwargs
        )
        plt.title('Interaction Strength', fontweight="bold")
    else:
        raise ValueError("Invalid plot type. Choose 'heatmap' or 'chord'.")
    
    plt.show()

# %%
from types import MappingProxyType
from anndata import AnnData
from matplotlib import colors as mcolors
from collections.abc import Callable, Mapping, Sequence

import os
from collections.abc import Callable, Mapping, Sequence
from functools import wraps
from inspect import signature
from pathlib import Path
from types import MappingProxyType
from typing import TYPE_CHECKING, Any, Optional, Union


import matplotlib as mpl
import numpy as np
import pandas as pd
from anndata import AnnData
from dask import array as da
from dask import delayed
from matplotlib import colors as mcolors
from matplotlib import pyplot as plt
from matplotlib.axes import Axes
from matplotlib.figure import Figure
from mpl_toolkits.axes_grid1 import make_axes_locatable
from numba import njit, prange
from pandas import CategoricalDtype
from pandas._libs.lib import infer_dtype
from pandas.core.dtypes.common import (
    is_bool_dtype,
    is_integer_dtype,
    is_numeric_dtype,
    is_object_dtype,
    is_string_dtype,
)
from scanpy import logging as logg
from scanpy import settings
from scipy.cluster import hierarchy as sch
from scipy.sparse import issparse, spmatrix
from skimage import img_as_float32
from skimage.color import rgb2gray

from squidpy._constants._pkg_constants import Key
from squidpy._docs import d
from squidpy._utils import NDArrayA
def _heatmap(
    adata: AnnData,
    key: str,
    title: str = "",
    method: str | None = None,
    cont_cmap: str | mcolors.Colormap = "viridis",
    annotate: bool = True,
    figsize: tuple[float, float] | None = None,
    dpi: int | None = None,
    cbar_kwargs: Mapping[str, Any] = MappingProxyType({}),
    ax: Axes | None = None,
    **kwargs: Any,
) -> mpl.figure.Figure:
    _assert_categorical_obs(adata, key=key)

    cbar_kwargs = dict(cbar_kwargs)

    if ax is None:
        fig, ax = plt.subplots(constrained_layout=True, dpi=dpi, figsize=figsize)
    else:
        fig = ax.figure

    if method is not None:
        row_order, col_order, _, col_link = _dendrogram(adata.X, method, optimal_ordering=adata.n_obs <= 1500)
    else:
        row_order = col_order = np.arange(len(adata.uns[Key.uns.colors(key)])).tolist()

    row_order = row_order[::-1]
    row_labels = adata.obs[key].iloc[row_order]
    data = adata[row_order, col_order].X

    row_cmap, col_cmap, row_norm, col_norm, n_cls = _get_cmap_norm(adata, key, order=(row_order, col_order))

    row_sm = mpl.cm.ScalarMappable(cmap=row_cmap, norm=row_norm)
    col_sm = mpl.cm.ScalarMappable(cmap=col_cmap, norm=col_norm)

    norm = mpl.colors.Normalize(
        vmin=kwargs.pop("vmin", np.nanmin(data)),
        vmax=kwargs.pop("vmax", np.nanmax(data)),
    )
    if isinstance(cont_cmap, str):
        cont_cmap = plt.colormaps[cont_cmap]
    cont_cmap.set_bad(color="grey")

    im = ax.imshow(data[::-1], cmap=cont_cmap, norm=norm)

    ax.grid(False)
    ax.tick_params(top=False, bottom=False, labeltop=False, labelbottom=False)
    ax.set_xticks([])
    ax.set_yticks([])

    if annotate:
        _annotate_heatmap(im, cmap=cont_cmap, **kwargs)

    divider = make_axes_locatable(ax)
    row_cats = divider.append_axes("left", size="2%", pad=0)
    col_cats = divider.append_axes("top", size="2%", pad=0)
    cax = divider.append_axes("right", size="1%", pad=0.1)
    if method is not None:  # cluster rows but don't plot dendrogram
        col_ax = divider.append_axes("top", size="5%")
        sch.dendrogram(
            col_link,
            no_labels=True,
            ax=col_ax,
            color_threshold=0,
            above_threshold_color="black",
        )
        col_ax.axis("off")

    _ = fig.colorbar(
        im,
        cax=cax,
        ticks=np.linspace(norm.vmin, norm.vmax, 10),
        orientation="vertical",
        format="%0.2f",
        **cbar_kwargs)

    # column labels colorbar
    c = fig.colorbar(col_sm, cax=col_cats, orientation="horizontal")
    c.set_ticks([])
    (col_cats if method is None else col_ax).set_title(title)

    # row labels colorbar
    c = fig.colorbar(row_sm, cax=row_cats, orientation="vertical", ticklocation="left")
    c.set_ticks(np.arange(n_cls) + 0.5)
    c.set_ticklabels(row_labels)
    c.set_label(key)

    return fig

# %%
title=None
annotate=False
method=None
figsize=None
dpi=20
cbar_kwargs = MappingProxyType({}),
ad = AnnData(X=celltype_ints, obs={'cluster_key': pd.Categorical(source_table.var.index)})
#maybe_set_colors(source=adata, target=ad, key=cluster_key, palette=palette)
if title is None:
    title = "Interaction matrix"
fig = _heatmap(
        ad,
        key='cluster_key',
        title='title',
        method=None,
        cont_cmap=cmap,
        annotate=annotate,
        figsize=(2 * ad.n_obs // 3, 2 * ad.n_obs // 3) if figsize is None else figsize,
        dpi=dpi,
        cbar_kwargs=cbar_kwargs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 11
#       9 if title is None:
#      10     title = "Interaction matrix"
# ---> 11 fig = _heatmap(
#      12         ad,
#      13         key='cluster_key',
#      14         title='title',
#      15         method=None,
#      16         cont_cmap=cmap,
#      17         annotate=annotate,
#      18         figsize=(2 * ad.n_obs // 3, 2 * ad.n_obs // 3) if figsize is None else figsize,
#      19         dpi=dpi,
#      20         cbar_kwargs=cbar_kwargs,
#      21     )
#
# Cell In[101], line 59, in _heatmap(adata, key, title, method, cont_cmap, annotate, figsize, dpi, cbar_kwargs, ax, **kwargs)
#      46 def _heatmap(
#      47     adata: AnnData,
#      48     key: str,
#    (...)
#      57     **kwargs: Any,
#      58 ) -> mpl.figure.Figure:
# ---> 59     _assert_categorical_obs(adata, key=key)
#      61     cbar_kwargs = dict(cbar_kwargs)
#      63     if ax is None:
#
# NameError: name '_assert_categorical_obs' is not defined

# %%
plot_celltype_interaction(sdata, kind='heatmap', celltype_key='cell type', vmax=None, vmin=None, cmap='BuPu',figsize=(5,5),cbar_pos=(.001, .42, .003, .2),
                   linewidths=.75)

# %%
#### PLOTTING 2: CELL TYPE-CELLTYPE INTERACTION STENGHT
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

#input
sdata
kind='heatmap'
celltype_key='cell type'
vmax=None
vmin=None
cmap='BuPu'
**kwargs


celltype_ints=np.mean(interaction_strength,axis=0)
celltype_ints_table=pd.DataFrame(celltype_ints,index=source_table.var.index,columns=target_table.var.index)
interaction_strength=sdata['source_score'].uns['interaction_strength']
source_table=sdata['source_score']
target_table=sdata['target_score']
try: 
    colors=sdata['table'].uns[celltype_key+'_colors']
except:
    colpalette = plt.get_cmap("tab20")
    colors = [colpalette(i) for i in range(len(np.unique(source_table.var.index)))]

if kind=='heatmap':
    sns.clustermap(celltype_ints_table,vmax=vmax,vmin=None,cmap=cmap,row_colors=colors, col_colors=colors,**kwargs)
    plt.title('Interaction strenght', fontweight="bold")
if kind == 'chord':
    cmap = plt.get_cmap("tab20")
    chord_diagram(
        celltype_ints,
        source_table.var.index,
        directed=True,
        fontsize=10,
        colors=colors,**kwargs
    )
    plt.title('Interaction strenght', fontweight="bold")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 25
#      22     colors = [colpalette(i) for i in range(len(np.unique(source_table.var.index)))]
#      24 if kind=='heatmap':
# ---> 25     sns.clustermap(celltype_ints_table,vmax=vmax,vmin=None,cmap=cmap,row_colors=colors, col_colors=colors,**kwargs)
#      26 if kind == 'chord':
#      27     cmap = plt.get_cmap("tab20")
#
# NameError: name 'kwargs' is not defined

# %%
from mpl_chord_diagram import chord_diagram

# %%
### PLOTTING 1: GENE SPECIFIC exRNA INTERACTION STRENGHT
## Downstream plot ###

import seaborn as sns
import matplotlib.pyplot as plt

gene_selected='Gfap'
celltype_ints_table=pd.DataFrame(result_matrix[(unique_cats==gene_selected),:,:].squeeze(),index=source_table.var.index,columns=target_table.var.index)

sns.clustermap(celltype_ints_table)
plt.title(gene_selected)
# WORK ON THIS FUNCTION SINCE IT'S CURRENTLY NOT WORKING WELL
# interactions_Vxn=troutpy.tl.get_gene_interaction_strength(source_proportion, target_proportion,gene_symbol="Gfap")

# %% [markdown]
# # Further develop-  Directionality analysis

# %%
from spatialdata import SpatialData 
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def analyze_transcript_distribution_with_edge_correction(
    sdata: SpatialData,
    layer="transcripts",
    gene_id_column="feature_name",
    xcoord="x",
    ycoord="y",
    xcellcoord="x_centroid",
    ycellcoord="y_centroid",
    resolution=12,
    max_distance=50,
    edge_buffer=20,
    radius=30,  # New parameter: radius to consider for nearby transcripts
    copy=False,
):
    """
    Analyzes the extracellular distribution of transcripts for diffusion patterns and directionality,
    accounting for edge effects. Now, it considers only transcripts within a certain radius from each cell.

    Parameters
    ----------
    - radius (float, optional)
        Maximum distance (radius) from each cell to consider relevant transcripts. Default is 10 units.
    - edge_buffer (float, optional)
        Minimum distance from the boundary for cells to be included in the analysis. Default is 20 units.
    """
    # Extract spatial bounds of the region
    transcripts = sdata.points[layer].compute()
    cells = sdata["table"].to_df()
    coord_cells = sdata["table"].obsm["spatial"]
    transcripts = transcripts[transcripts["extracellular"] == False]
    
    # Get spatial bounds
    x_min, y_min = coord_cells.min(axis=0)
    x_max, y_max = coord_cells.max(axis=0)

    # Filter edge cells
    edge_mask = (
        (coord_cells[:, 0] > x_min + edge_buffer)
        & (coord_cells[:, 0] < x_max - edge_buffer)
        & (coord_cells[:, 1] > y_min + edge_buffer)
        & (coord_cells[:, 1] < y_max - edge_buffer)
    )
    valid_cells = cells[edge_mask]
    valid_coords = coord_cells[edge_mask]

    # Initialize results
    results = []

    for gene in tqdm(cells.columns.unique(), desc="Processing genes"):
        # Filter transcripts and edge-corrected cells for the current gene
        gene_transcripts = transcripts[transcripts[gene_id_column] == gene]
        gene_cells = valid_cells[valid_cells[gene] > 0]
        if gene_transcripts.empty or gene_cells.empty:
            continue

        # Extract coordinates
        transcript_coords = gene_transcripts[[xcoord, ycoord]].to_numpy()
        cell_coords = valid_coords[valid_cells[gene] > 0]

        # Radial distribution with edge correction (only for relevant transcripts within radius)
        radial_bins = np.linspace(0, max_distance, 50)
        radial_density = np.zeros_like(radial_bins[:-1], dtype=float)
        
        for cell_idx, cell_coord in enumerate(cell_coords):
            # Find transcripts within the specified radius around the current cell
            dists_to_transcripts = np.linalg.norm(transcript_coords - cell_coord, axis=1)
            relevant_transcripts = transcript_coords[dists_to_transcripts <= radius]  # Filter by distance
            
            if relevant_transcripts.shape[0] == 0:  # No transcripts in range
                continue
            
            # Compute distances to relevant transcripts
            dists = dists_to_transcripts[dists_to_transcripts <= radius]
            
            # Add the histogram of distances for this cell
            radial_density += np.histogram(dists, bins=radial_bins, density=True)[0]

        radial_density /= len(cell_coords)  # Normalize by the number of valid cells

        # Symmetry score
        decay_model = np.exp(-radial_bins[:-1] / (max_distance / 2))
        symmetry_score = np.corrcoef(radial_density, decay_model)[0, 1]

        # Directionality analysis with angular density
        angles = np.arctan2(
            transcript_coords[:, 1][:, None] - cell_coords[:, 1],
            transcript_coords[:, 0][:, None] - cell_coords[:, 0],
        )
        angles = angles % (2 * np.pi)
        angular_bins = np.linspace(0, 2 * np.pi, resolution + 1)
        angular_density = np.zeros(resolution, dtype=float)
        for sector_idx in range(resolution):
            sector_mask = (
                (angles >= angular_bins[sector_idx])
                & (angles < angular_bins[sector_idx + 1])
            )
            angular_density[sector_idx] = sector_mask.sum() / transcript_coords.shape[0]
        
        # Directionality score
        directionality_score = np.var(angular_density)
        #if directionality_score>1000:
        #    plt.figure()
        #    sns.barplot(angular_density)
        #    plt.title(gene)
        #    plt.show()



        # Store results
        results.append({
            "gene": gene,
            "symmetry_score": symmetry_score,
            "directionality_score": directionality_score,
        })

    # Convert to DataFrame
    results_df = pd.DataFrame(results)

    if copy:
        return sdata.copy(), results_df
    else:
        return results_df

# %%
results_df=analyze_transcript_distribution_with_edge_correction(
    sdata, layer="transcripts", gene_id_column="feature_name",
 xcoord="x", ycoord="y",xcellcoord="x_centroid",ycellcoord="y_centroid",
    resolution=12, max_distance=50, edge_buffer=20, copy=False)
# Out:
# Processing genes:   0%|          | 0/4226 [00:00<?, ?it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   0%|          | 15/4226 [00:00<00:28, 149.51it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   1%|          | 30/4226 [00:00<00:45, 91.95it/s] /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   1%|          | 41/4226 [00:00<00:43, 95.38it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   1%|▏         | 60/4226 [00:00<01:24, 49.29it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   2%|▏         | 86/4226 [00:01<02:15, 30.49it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   2%|▏         | 99/4226 [00:02<01:59, 34.63it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   2%|▏         | 105/4226 [00:02<01:51, 36.89it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   3%|▎         | 121/4226 [00:02<01:12, 56.71it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   3%|▎         | 130/4226 [00:02<01:17, 52.63it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   3%|▎         | 143/4226 [00:02<01:01, 66.68it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   4%|▎         | 156/4226 [00:02<00:51, 78.62it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   4%|▍         | 166/4226 [00:04<03:28, 19.47it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   4%|▍         | 173/4226 [00:04<03:04, 21.94it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   4%|▍         | 182/4226 [00:04<02:28, 27.25it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   5%|▍         | 197/4226 [00:04<01:51, 36.12it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   5%|▌         | 219/4226 [00:05<01:47, 37.25it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   5%|▌         | 226/4226 [00:05<01:38, 40.80it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   6%|▌         | 233/4226 [00:05<01:35, 41.93it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   6%|▌         | 246/4226 [00:06<01:39, 39.82it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   6%|▌         | 259/4226 [00:06<01:24, 46.72it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   6%|▋         | 265/4226 [00:06<01:20, 49.02it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   7%|▋         | 278/4226 [00:06<01:17, 50.96it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   7%|▋         | 286/4226 [00:06<01:07, 58.26it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   7%|▋         | 303/4226 [00:07<00:59, 65.89it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   8%|▊         | 339/4226 [00:08<01:38, 39.36it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   8%|▊         | 348/4226 [00:08<01:24, 45.79it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   9%|▉         | 370/4226 [00:08<00:57, 66.62it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   9%|▉         | 379/4226 [00:08<00:55, 69.07it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   9%|▉         | 388/4226 [00:09<01:04, 59.83it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:   9%|▉         | 396/4226 [00:09<00:59, 64.15it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  10%|▉         | 404/4226 [00:09<00:59, 64.56it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  10%|▉         | 417/4226 [00:09<00:52, 72.37it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  10%|█         | 426/4226 [00:09<00:52, 73.03it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  10%|█         | 434/4226 [00:09<01:04, 58.82it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  11%|█         | 462/4226 [00:10<00:48, 77.22it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  11%|█         | 470/4226 [00:10<00:56, 66.24it/s]
# Processing genes:  12%|█▏        | 500/4226 [00:14<03:43, 16.66it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  13%|█▎        | 533/4226 [00:14<01:31, 40.45it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  13%|█▎        | 551/4226 [00:15<01:02, 58.61it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  13%|█▎        | 563/4226 [00:15<01:01, 59.61it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  14%|█▍        | 589/4226 [00:15<00:40, 89.61it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  14%|█▍        | 603/4226 [00:15<00:39, 91.39it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  15%|█▍        | 616/4226 [00:15<00:42, 85.02it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  15%|█▍        | 629/4226 [00:15<00:38, 93.57it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  16%|█▌        | 660/4226 [00:16<01:16, 46.82it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  16%|█▌        | 677/4226 [00:16<00:54, 64.78it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  17%|█▋        | 709/4226 [00:16<00:37, 93.34it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  17%|█▋        | 722/4226 [00:17<00:34, 101.02it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  17%|█▋        | 735/4226 [00:17<00:35, 99.33it/s] /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  18%|█▊        | 747/4226 [00:18<02:29, 23.25it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  18%|█▊        | 766/4226 [00:18<01:39, 34.92it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  18%|█▊        | 778/4226 [00:19<01:32, 37.22it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  19%|█▊        | 788/4226 [00:19<01:25, 40.35it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  19%|█▉        | 809/4226 [00:19<00:56, 60.47it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  19%|█▉        | 824/4226 [00:19<00:47, 72.18it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  20%|█▉        | 837/4226 [00:19<00:49, 69.10it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  20%|██        | 848/4226 [00:19<00:48, 69.29it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# ...
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  55%|█████▌    | 2341/4226 [00:46<00:27, 67.35it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  56%|█████▌    | 2349/4226 [00:46<00:27, 68.07it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  56%|█████▌    | 2359/4226 [00:46<00:24, 75.65it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  56%|█████▌    | 2368/4226 [00:47<00:30, 61.62it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  57%|█████▋    | 2396/4226 [00:47<00:29, 61.50it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  58%|█████▊    | 2432/4226 [00:47<00:25, 71.57it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  58%|█████▊    | 2446/4226 [00:48<00:21, 84.25it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  58%|█████▊    | 2458/4226 [00:48<00:19, 91.74it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  58%|█████▊    | 2469/4226 [00:48<00:22, 79.39it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  59%|█████▊    | 2479/4226 [00:48<00:22, 77.34it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  60%|█████▉    | 2518/4226 [00:49<00:57, 29.58it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  60%|█████▉    | 2530/4226 [00:50<00:38, 43.74it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  60%|██████    | 2546/4226 [00:50<00:35, 46.95it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  61%|██████    | 2570/4226 [00:50<00:20, 80.36it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  61%|██████    | 2582/4226 [00:50<00:18, 88.50it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  61%|██████▏   | 2593/4226 [00:50<00:17, 91.01it/s]/home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/sergio/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Processing genes:  62%|██████▏   | 2620/4226 [00:51<00:31, 51.29it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 results_df=analyze_transcript_distribution_with_edge_correction(
#       2     sdata, layer="transcripts", gene_id_column="feature_name",
#       3  xcoord="x", ycoord="y",xcellcoord="x_centroid",ycellcoord="y_centroid",
#       4     resolution=12, max_distance=50, edge_buffer=20, copy=False)
#
# Cell In[93], line 83, in analyze_transcript_distribution_with_edge_correction(sdata, layer, gene_id_column, xcoord, ycoord, xcellcoord, ycellcoord, resolution, max_distance, edge_buffer, radius, copy)
#      80     dists = dists_to_transcripts[dists_to_transcripts <= radius]
#      82     # Add the histogram of distances for this cell
# ---> 83     radial_density += np.histogram(dists, bins=radial_bins, density=True)[0]
#      85 radial_density /= len(cell_coords)  # Normalize by the number of valid cells
#      87 # Symmetry score
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/histograms.py:780, in histogram(a, bins, range, density, weights)
#     680 r"""
#     681 Compute the histogram of a dataset.
#     682
#    (...)
#     776
#     777 """
#     778 a, weights = _ravel_and_check_weights(a, weights)
# --> 780 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     782 # Histogram is an integer or a float array depending on the weights.
#     783 if weights is None:
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/histograms.py:430, in _get_bin_edges(a, bins, range, weights)
#     428 elif np.ndim(bins) == 1:
#     429     bin_edges = np.asarray(bins)
# --> 430     if np.any(bin_edges[:-1] > bin_edges[1:]):
#     431         raise ValueError(
#     432             '`bins` must increase monotonically, when an array')
#     434 else:
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2412, in any(a, axis, out, keepdims, where)
#    2322 @array_function_dispatch(_any_dispatcher)
#    2323 def any(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2324     """
#    2325     Test whether any array element along a given axis evaluates to True.
#    2326
#    (...)
#    2410
#    2411     """
# -> 2412     return _wrapreduction(a, np.logical_or, 'any', axis, None, out,
#    2413                           keepdims=keepdims, where=where)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
results_df.sort_values(by='directionality_score')
# Out:
#         gene  symmetry_score  directionality_score
# 1847    Isl1             NaN              0.016204
# 2356  Mybpc3             NaN              0.020833
# 1452    Gbx2             NaN              0.020833
# 1492    Gli1        0.238714              0.024306
# 511     Ccl2             NaN              0.028696
# ...      ...             ...                   ...
# 1514   Gnao1        0.476500           1935.214491
# 1412  Gabbr1        0.452468           1977.448116
# 3153   Rsrp1        0.661459           2100.943385
# 452   Camk2a        0.434861           2374.495205
# 2548    Nsmf        0.423479           2502.822304
#
# [4084 rows x 3 columns]

# %%
sft=sdata['segmentation_free_table']
sft2=sc.pp.subsample(sft,0.01,copy=True)

# %%
genes= results_df.sort_values(by='directionality_score').tail(10)

# %%
genes.sort_values(by='symmetry_score')
# Out:
#          gene  symmetry_score  directionality_score
# 2548     Nsmf        0.423479           2502.822304
# 452    Camk2a        0.434861           2374.495205
# 3720     Thra        0.444800           1888.576048
# 2884  Prkar1a        0.448194           1766.259082
# 197     Ap2b1        0.449065           1768.344126
# 1412   Gabbr1        0.452468           1977.448116
# 1514    Gnao1        0.476500           1935.214491
# 704       Ckb        0.518452           1836.875201
# 569      Cd81        0.578081           1835.301502
# 3153    Rsrp1        0.661459           2100.943385

# %%
transcripts = sdata.points['transcripts'].compute()
transcripts = transcripts[transcripts["extracellular"]==False]
transcripts=transcripts[transcripts['extracellular']==False]

# %%
import scanpy as sc
import matplotlib.pyplot as plt
for gene in genes['gene'][0:2]:
    print(gene)
    sc.pl.spatial(sdata['table'],color=gene,spot_size=10,cmap='Reds',show=False,vmax=2)
    transcripts_sub=transcripts[transcripts['feature_name']==gene]
    plt.scatter(transcripts_sub['x'],transcripts_sub['y'],color='blue',s=0.2)
# Out:
# Prkar1a
# Ap2b1

# %% [markdown]
# # Explore communications

# %%
def communicating_genes_per_celltype(sdata, proportion_threshold: float = 0.2, cell_type_key="cell type"):
    """Computes the number of significant genes exchanged between source and target cell types based on their proportions in the dataset.

    Parameters
    ----------
    - sdata: AnnData object
    A spatial data object containing the 'table' and 'xrna_metadata' components.
    - proportion_threshold: float, optional (default=0.2)
    The threshold for filtering significant gene proportions. Genes with proportions above this value are considered significant.
    - cell_type_key: str, optional (default='cell type')
    The key in `adata.obs` that contains the cell type annotations.

    Returns
    -------
    - number_interactions_df: pandas.DataFrame
    A DataFrame where rows represent source cell types, columns represent target cell types, and values indicate the number of significant genes shared between them.
    """
    adata = sdata["table"]
    source_proportions = pd.DataFrame(
        sdata["xrna_metadata"].varm["source"], index=sdata["xrna_metadata"].var.index, columns=adata.obs[cell_type_key].unique().dropna()
    )
    target_proportions = pd.DataFrame(
        sdata["xrna_metadata"].varm["target"], index=sdata["xrna_metadata"].var.index, columns=adata.obs[cell_type_key].unique().dropna()
    )

    # filter the source and target cell types by defining significant proportions
    source_binary = source_proportions > proportion_threshold
    target_binary = target_proportions > proportion_threshold

    # prepare dataframe to store the number of exchanged genes
    number_interactions_df = pd.DataFrame(index=source_binary.columns, columns=target_binary.columns)

    # loop through the source and target cell types to compute the number of
    # exchanged genes
    for col in source_binary.columns:
        sig_gene_source = source_binary.index[source_binary[col]]
        for col2 in target_binary.columns:
            sig_gene_target = target_binary.index[target_binary[col2]]
            number_interactions_df.loc[col, col2] = len(set(sig_gene_source).intersection(sig_gene_target))

    number_interactions_df = number_interactions_df[number_interactions_df.index]
    number_interactions_df.columns.name = "Target cell type"
    number_interactions_df.index.name = "Source cell type"
    return number_interactions_df

# %%
communications_ngenes = communicating_genes_per_celltype(sdata, proportion_threshold=0.6, cell_type_key="cell type")

# %%
troutpy.pl.sorted_heatmap(communications_ngenes.astype(float), save=False, figsize=(5, 5))

# %%
troutpy.pl.spatial_interactions(sdata, layer="extracellular_transcripts_enriched", gene="Arc", gene_key="feature_name", figsize=(5, 5))
# Out:
# /tmp/ipykernel_1020010/2393974738.py:46: DeprecationWarning: Table accessor will be deprecated with SpatialData version 0.1, use sdata.tables instead.
#   cell_positions = pd.DataFrame(sdata['table'].obsm[spatial_key], index=sdata.table.obs[cell_id_key], columns=['x', 'y'])

# %%
troutpy.pl.interactions_with_arrows(
    sdata, layer="extracellular_transcripts_enriched", gene="Kif5a", gene_key="feature_name", figsize=(7, 7), dpi=100, size=5
)
# Out:
# /tmp/ipykernel_1020010/732527654.py:35: DeprecationWarning: Table accessor will be deprecated with SpatialData version 0.1, use sdata.tables instead.
#   cell_positions = pd.DataFrame(sdata['table'].obsm[spatial_key], index=sdata.table.obs[cell_id_key], columns=['x', 'y'])
